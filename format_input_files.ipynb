# %% [markdown]
# ## Temperature Sensitivity Analysis

# %%
def modify_lines_temp(file_path, new_file, sk5):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    lines[229] =   '  FINAL_TIME 4000.d0 h\n'

    modified_lines = []
    for line in lines[894:1015]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[894:1015] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[607:699]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[607:699] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[471:591]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[471:591] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[337:455]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    modified_data = '\n'.join(modified_lines)
    lines[337:455] = modified_data+'\n'

    
    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)

base = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper'

import os
import pandas as pd
import numpy as np
import re
import random



file_path = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_highgaining.in'

files = os.listdir(base)

count=0
count4=0
for i in range(6):
    sk5 = i*5-5

    #sk5 = 


    file_path_new = base+'/input_files/fullsim_high_gaining_temp'+str(i)+'.in'
    print(file_path_new)
    # Open and read the file
    modify_lines_temp(file_path, file_path_new, sk5)
# Out:
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_temp0.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_temp1.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_temp2.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_temp3.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_temp4.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_temp5.in

# %% [markdown]
# ## Up-Down Pressure Sensitivity Analysis

# %%
def modify_lines_press_ud(file_path, new_file, sk5):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    lines[229] =   '  FINAL_TIME 4000.d0 h\n'
    
    
    modified_lines = []
    for line in lines[704:869]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str((float(parts[1])*sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[704:869] = modified_data+'\n'

    
    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)

base = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper'

import os
import pandas as pd
import numpy as np
import re
import random



file_path = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_highgaining.in'

files = os.listdir(base)

count=0
count4=0
for i in range(6):
    sk5 = i*.5+.25

    #sk5 = 


    file_path_new = base+'/input_files/fullsim_high_gaining_press_ud'+str(i)+'.in'
    print(file_path_new)
    # Open and read the file
    modify_lines_press_ud(file_path, file_path_new, sk5)
# Out:
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_press_ud0.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_press_ud1.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_press_ud2.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_press_ud3.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_press_ud4.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_press_ud5.in

# %% [markdown]
# ## Left-Right Pressure Sensitivity Analysis

# %%
def modify_lines_press_lr(file_path, new_file, sk5):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    lines[229] =   '  FINAL_TIME 4000.d0 h\n'
    
    lines[329] =   '  LIQUID_PRESSURE ' + str(210.65+100*sk5) + 'd0\n'
    
    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)

base = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper'

import os
import pandas as pd
import numpy as np
import re
import random



file_path = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_highgaining.in'

files = os.listdir(base)

count=0
count4=0
for i in range(6):
    sk5 = i*2

    #sk5 = 


    file_path_new = base+'/input_files/fullsim_high_gaining_press_lr'+str(i)+'.in'
    print(file_path_new)
    # Open and read the file
    modify_lines_press_lr(file_path, file_path_new, sk5)
# Out:
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_press_lr0.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_press_lr1.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_press_lr2.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_press_lr3.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_press_lr4.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_press_lr5.in

# %% [markdown]
# ## Biomass Crowding (Exp B) Sensitivity Analysis

# %%
    lines[79] =  '       RATE_B_1             '+'{:.{}g}'.format(sk2, 6)+'d-5       # lambda_B1 [/s]\n'

# %%
def modify_lines_expB(file_path, new_file, sk5):
    with open(file_path, 'r') as file:
        lines = file.readlines()    
    lines[229] =   '  FINAL_TIME 4000.d0 h\n'

    lines[65] =  '       EXPONENT_B           '+'{:.{}g}'.format(sk5, 6)+'         # alpha [-]\n'
    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)

base = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper'
file_path = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_highgaining.in'
files = os.listdir(base)
for i in range(6):
    sk5 = 3-i*.3
    file_path_new = base+'/input_files/fullsim_high_gaining_expB'+str(i)+'.in'
    print(file_path_new)
    modify_lines_expB(file_path, file_path_new, sk5)
# Out:
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_expB0.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_expB1.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_expB2.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_expB3.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_expB4.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_expB5.in

# %% [markdown]
# ## Biomass Growth (B1) Sensitivity Analysis

# %%
def modify_lines_B1(file_path, new_file, sk5):
    with open(file_path, 'r') as file:
        lines = file.readlines() 
    lines[229] =   '  FINAL_TIME 4000.d0 h\n'

    lines[79] =  '       RATE_B_1             '+'{:.{}g}'.format(sk5, 6)+'d-5       # lambda_B1 [/s]\n'
    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)

base = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper'
file_path = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_highgaining.in'
files = os.listdir(base)
for i in range(8):
    sk5 = 1.8-i*.2
    file_path_new = base+'/input_files/fullsim_high_gaining_B1'+str(i)+'.in'
    print(file_path_new)
    modify_lines_B1(file_path, file_path_new, sk5)
# Out:
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_B10.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_B11.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_B12.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_B13.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_B14.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_B15.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_B16.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_B17.in

# %% [markdown]
# ## Biotic Reduction Strength (rate_c) Sensitivity Analysis

# %%
def modify_lines_c(file_path, new_file, sk5):
    with open(file_path, 'r') as file:
        lines = file.readlines() 
    lines[229] =   '  FINAL_TIME 4000.d0 h\n'

    lines[81] =  '       RATE_C             '+'{:.{}g}'.format(sk5, 6)+'d-9       # lambda_B1 [/s]\n'
    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)

base = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper'
file_path = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_highgaining.in'
files = os.listdir(base)
for i in range(6):
    sk5 = 4-i*.5
    file_path_new = base+'/input_files/fullsim_high_gaining_c'+str(i)+'.in'
    print(file_path_new)
    modify_lines_c(file_path, file_path_new, sk5)
# Out:
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_c0.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_c1.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_c2.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_c3.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_c4.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_c5.in

# %% [markdown]
# ## Carbon Reuse Efficiency (D1) Sensitivity Analysis

# %%
def modify_lines_d1(file_path, new_file, sk5):
    with open(file_path, 'r') as file:
        lines = file.readlines()    
    lines[229] =   '  FINAL_TIME 4000.d0 h\n'

    lines[94] =  '       STOICHIOMETRIC_D_1   '+'{:.{}g}'.format(sk5, 6)+'d-1       # S_D_1 [-]\n'
    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)

base = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper'
file_path = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_highgaining.in'
files = os.listdir(base)
for i in range(6):
    sk5 = 10-(1.5*i)
    file_path_new = base+'/input_files/fullsim_high_gaining_d1'+str(i)+'.in'
    print(file_path_new)
    modify_lines_d1(file_path, file_path_new, sk5)
# Out:
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_d10.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_d11.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_d12.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_d13.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_d14.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_d15.in

# %% [markdown]
# ## Permeability Correlation Length Sensitivity Analysis
# ### (Proxy for soil heterogeneity)

# %%
def modify_lines_perm1(file_path, new_file, i):
    with open(file_path, 'r') as file:
        lines = file.readlines()    
    lines[229] =   '  FINAL_TIME 4000.d0 h\n'
    lines[160] =   '  FILENAME ../gstools_'+i+'_2xscale_perm.h5' + '\n'
    lines[164] =   '  FILENAME ../gstools_'+i+'_2xscale_porosity.h5' + '\n'
    lines[170] =   '  FILENAME ../gstools_'+i+'_2xscale_min_vol.h5' + '\n'    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)


base = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper'
file_path = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_highgaining.in'
perms=['18_10', '27_14', '33_15', '36_18', '40_20', '50_25']
count = 0
for i in perms:
    file_path_new = base+'/input_files/fullsim_high_gaining_perm_maxL'+str(count)+'.in'
    print(file_path_new)
    modify_lines_perm1(file_path, file_path_new, i)
    count = count+1
# Out:
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_maxL0.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_maxL1.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_maxL2.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_maxL3.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_maxL4.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_maxL5.in

# %%
def modify_lines_perm2(file_path, new_file, i):
    with open(file_path, 'r') as file:
        lines = file.readlines()    
    lines[229] =   '  FINAL_TIME 4000.d0 h\n'
    lines[160] =   '  FILENAME ../gstools_'+i+'_2xscale_perm.h5' + '\n'
    lines[164] =   '  FILENAME ../gstools_'+i+'_2xscale_porosity.h5' + '\n'
    lines[170] =   '  FILENAME ../gstools_'+i+'_2xscale_min_vol.h5' + '\n'    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)
perms=['17_22', '18_19', '22_21', '22_16', '14_10', '18_10']

base = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper'
file_path = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_highgaining.in'
count = 0
for i in perms:
    file_path_new = base+'/input_files/fullsim_high_gaining_perm_ratio'+str(count)+'.in'
    print(file_path_new)
    modify_lines_perm2(file_path, file_path_new, i)
    count = count+1
# Out:
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_ratio0.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_ratio1.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_ratio2.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_ratio3.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_ratio4.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_ratio5.in

# %% [markdown]
# ## Permeability Sensitivity Analysis (homogeneous)

# %%
def modify_lines_perm3(file_path, new_file, i):
    with open(file_path, 'r') as file:
        lines = file.readlines()    
    lines[185] =   '  PERM_ISO '+'{:.{}g}'.format(i, 6)+'d-12'+'\n'
    
    with open(new_file, 'w') as file:
        file.writelines(lines)
perms=[1000, 100, 10, 1, .1, .01]

base = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper'
file_path = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_highgaining.in'
count = 0
for i in perms:
    file_path_new = base+'/input_files/fullsim_high_gaining_perm_homo'+str(count)+'.in'
    print(file_path_new)
    modify_lines_perm3(file_path, file_path_new, i)
    count = count+1
# Out:
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_homo0.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_homo1.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_homo2.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_homo3.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_homo4.in
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_high_gaining_perm_homo5.in

# %% [markdown]
# ## Scale Sensitivity Analysis (simulations already run)

# %% [markdown]
# ## Formatting Change for Upscaling and generation of different simulations needed for sensitivity analysis of Chromium reduction

# %%
def modify_lines_gain(file_path, new_file,i,count, skewed_number, sk2, sk3, sk4, sk5, sk6, sk7, sk8,sk9,sk10,sk11,sk12,sk13,sk14):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Changing line 100 (index 99 in Python)
    print (i.split('_'))
    #if count%10
    lines[65] =  '       EXPONENT_B           '+'{:.{}g}'.format(skewed_number, 6)+'         # alpha [-]\n'
    lines[79] =  '       RATE_B_1             '+'{:.{}g}'.format(sk2, 6)+'d-5       # lambda_B1 [/s]\n'
    lines[81] =  '       RATE_C             '+'{:.{}g}'.format(sk3, 6)+'d-9       # lambda_B1 [/s]\n'
    lines[94] =  '       STOICHIOMETRIC_D_1   '+'{:.{}g}'.format(sk4, 6)+'d-1       # S_D_1 [-]\n'
    lines[160] =   '  FILENAME ../gstools_'+i+'_perm.h5' + '\n'
    lines[164] =   '  FILENAME ../gstools_'+i+'_porosity.h5' + '\n'
    lines[170] =   '  FILENAME ../gstools_'+i+'_min_vol.h5' + '\n'
    lines[229] =   '  FINAL_TIME 5400.d0 h\n'
    if '10x' in i:
        lines[152] =   '  NXYZ 100 ' + str(int(i.split('_')[2][0:2])*200) + ' 1\n'
        lines[155] =   '    1.d0 ' + str(int(i.split('_')[2][0:2])*2) + '.d0 1.d0\n'
        lines[246] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[258] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[271] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[278] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[279] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[296] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[304] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
    else:
        lines[152] =   '  NXYZ 100 ' + str(int(i.split('_')[2][0])*200) + ' 1\n'
        lines[155] =   '    1.d0 ' + str(int(i.split('_')[2][0])*2) + '.d0 1.d0\n'
        lines[246] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[258] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[271] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[278] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[279] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[296] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[304] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
    lines[329] =   '  LIQUID_PRESSURE ' + str(int(i.split('_')[2][0])*210.65*sk6) + 'd0\n'
    lines[732] =  '    molasses    '+'{:.{}g}'.format(sk7, 6)+'d-5 T\n'
    lines[743] =  '    molasses    '+'{:.{}g}'.format(sk8, 6)+'d-5 T\n'
    lines[754] =  '    molasses    '+'{:.{}g}'.format(sk9, 6)+'d-5 T\n'
    lines[765] =  '    molasses    '+'{:.{}g}'.format(sk10, 6)+'d-5 T\n'
    lines[735] =  '    Cr(VI)    '+'{:.{}g}'.format(sk11, 6)+'d-5 T\n'
    lines[746] =  '    Cr(VI)    '+'{:.{}g}'.format(sk12, 6)+'d-5 T\n'
    lines[757] =  '    Cr(VI)    '+'{:.{}g}'.format(sk13, 6)+'d-5 T\n'
    lines[768] =  '    Cr(VI)    '+'{:.{}g}'.format(sk14, 6)+'d-5 T\n'

    modified_lines = []
    for line in lines[547:645]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[547:645] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[380:522]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5*4))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[380:522] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[372:375]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[372:375] = modified_data+'\n'
    

    
    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)

# %%
# Since the file contains more than 100 lines, we can proceed to write a function to modify line 100



def modify_lines_highlose(file_path, new_file,i,count, skewed_number, sk2, sk3, sk4, sk5, sk6, sk7, sk8,sk9,sk10,sk11,sk12,sk13,sk14):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Changing line 100 (index 99 in Python)
    print (i.split('_'))
    #if count%10
    lines[65] =  '       EXPONENT_B           '+'{:.{}g}'.format(skewed_number, 6)+'         # alpha [-]\n'
    lines[79] =  '       RATE_B_1             '+'{:.{}g}'.format(sk2, 6)+'d-5       # lambda_B1 [/s]\n'
    lines[81] =  '       RATE_C             '+'{:.{}g}'.format(sk3, 6)+'d-9       # lambda_B1 [/s]\n'
    lines[94] =  '       STOICHIOMETRIC_D_1   '+'{:.{}g}'.format(sk4, 6)+'d-1       # S_D_1 [-]\n'
    lines[160] =   '  FILENAME ../gstools_'+i+'_perm.h5' + '\n'
    lines[164] =   '  FILENAME ../gstools_'+i+'_porosity.h5' + '\n'
    lines[170] =   '  FILENAME ../gstools_'+i+'_min_vol.h5' + '\n'
    lines[229] =   '  FINAL_TIME 5400.d0 h\n'
    if '10x' in i:
        lines[152] =   '  NXYZ 100 ' + str(int(i.split('_')[2][0:2])*200) + ' 1\n'
        lines[155] =   '    1.d0 ' + str(int(i.split('_')[2][0:2])*2) + '.d0 1.d0\n'
        lines[246] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[258] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[271] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[278] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[279] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[296] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[304] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
    else:
        lines[152] =   '  NXYZ 100 ' + str(int(i.split('_')[2][0])*200) + ' 1\n'
        lines[155] =   '    1.d0 ' + str(int(i.split('_')[2][0])*2) + '.d0 1.d0\n'
        lines[246] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[258] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[271] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[278] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[279] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[296] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[304] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
    lines[329] =   '  LIQUID_PRESSURE ' + str(int(i.split('_')[2][0])*210.65*sk6) + 'd0\n'
    lines[1093] =  '    molasses    '+'{:.{}g}'.format(sk7, 6)+'d-5 T\n'
    lines[1104] =  '    molasses    '+'{:.{}g}'.format(sk8, 6)+'d-5 T\n'
    lines[1115] =  '    molasses    '+'{:.{}g}'.format(sk9, 6)+'d-5 T\n'
    lines[1126] =  '    molasses    '+'{:.{}g}'.format(sk10, 6)+'d-5 T\n'
    lines[1096] =  '    Cr(VI)    '+'{:.{}g}'.format(sk11, 6)+'d-5 T\n'
    lines[1107] =  '    Cr(VI)    '+'{:.{}g}'.format(sk12, 6)+'d-5 T\n'
    lines[1118] =  '    Cr(VI)    '+'{:.{}g}'.format(sk13, 6)+'d-5 T\n'
    lines[1129] =  '    Cr(VI)    '+'{:.{}g}'.format(sk14, 6)+'d-5 T\n'

    modified_lines = []
    for line in lines[849:1012]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5*200))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[849:1012] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[724:843]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[724:843] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[602:692]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[602:692] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[469:586]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[469:586] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[336:453]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    modified_data = '\n'.join(modified_lines)
    lines[336:453] = modified_data+'\n'

    
    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)

# %%
# Since the file contains more than 100 lines, we can proceed to write a function to modify line 100



def modify_lines_hanford_gain(file_path, new_file,i,count, skewed_number, sk2, sk3, sk4, sk5, sk6, sk7, sk8,sk9,sk10,sk11,sk12,sk13,sk14,sk15):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Changing line 100 (index 99 in Python)
    print (i.split('_'))
    #if count%10
    lines[65] =  '       EXPONENT_B           '+'{:.{}g}'.format(skewed_number, 6)+'         # alpha [-]\n'
    lines[79] =  '       RATE_B_1             '+'{:.{}g}'.format(sk2, 6)+'d-5       # lambda_B1 [/s]\n'
    lines[81] =  '       RATE_C             '+'{:.{}g}'.format(sk3, 6)+'d-9       # lambda_B1 [/s]\n'
    lines[94] =  '       STOICHIOMETRIC_D_1   '+'{:.{}g}'.format(sk4, 6)+'d-1       # S_D_1 [-]\n'
    lines[160] =   '  FILENAME ../gstools_'+i+'_perm.h5' + '\n'
    lines[164] =   '  FILENAME ../gstools_'+i+'_porosity.h5' + '\n'
    lines[170] =   '  FILENAME ../gstools_'+i+'_min_vol.h5' + '\n'
    lines[229] =   '  FINAL_TIME 5400.d0 h\n'
    if '10x' in i:
        lines[152] =   '  NXYZ 100 ' + str(int(i.split('_')[2][0:2])*200) + ' 1\n'
        lines[155] =   '    1.d0 ' + str(int(i.split('_')[2][0:2])*2) + '.d0 1.d0\n'
        lines[246] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[258] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[271] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[278] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[279] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[296] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[304] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
    else:
        lines[152] =   '  NXYZ 100 ' + str(int(i.split('_')[2][0])*200) + ' 1\n'
        lines[155] =   '    1.d0 ' + str(int(i.split('_')[2][0])*2) + '.d0 1.d0\n'
        lines[246] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[258] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[271] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[278] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[279] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[296] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[304] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
    lines[329] =   '  LIQUID_PRESSURE ' + str(int(i.split('_')[2][0])*210.65*sk15*sk6) + 'd0\n'
    lines[1101] =  '    molasses    '+'{:.{}g}'.format(sk7, 6)+'d-5 T\n'
    lines[1112] =  '    molasses    '+'{:.{}g}'.format(sk8, 6)+'d-5 T\n'
    lines[1123] =  '    molasses    '+'{:.{}g}'.format(sk9, 6)+'d-5 T\n'
    lines[1134] =  '    molasses    '+'{:.{}g}'.format(sk10, 6)+'d-5 T\n'
    lines[1104] =  '    Cr(VI)    '+'{:.{}g}'.format(sk11, 6)+'d-5 T\n'
    lines[1115] =  '    Cr(VI)    '+'{:.{}g}'.format(sk12, 6)+'d-5 T\n'
    lines[1126] =  '    Cr(VI)    '+'{:.{}g}'.format(sk13, 6)+'d-5 T\n'
    lines[1137] =  '    Cr(VI)    '+'{:.{}g}'.format(sk14, 6)+'d-5 T\n'

    modified_lines = []
    for line in lines[894:1015]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[894:1015] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[704:869]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(-1*(float(parts[1]) +  round(sk5*100)))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[704:869] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[607:699]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[607:699] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[471:591]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[471:591] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[337:455]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    modified_data = '\n'.join(modified_lines)
    lines[337:455] = modified_data+'\n'

    
    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)

# %%
# Since the file contains more than 100 lines, we can proceed to write a function to modify line 100

import random


def modify_lines_highgain(file_path, new_file,i,count, skewed_number, sk2, sk3, sk4, sk5, sk6, sk7, sk8,sk9,sk10,sk11,sk12,sk13,sk14,sk15):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Changing line 100 (index 99 in Python)
    print (i.split('_'))
    #if count%10
    lines[65] =  '       EXPONENT_B           '+'{:.{}g}'.format(skewed_number, 6)+'         # alpha [-]\n'
    lines[79] =  '       RATE_B_1             '+'{:.{}g}'.format(sk2, 6)+'d-5       # lambda_B1 [/s]\n'
    lines[81] =  '       RATE_C             '+'{:.{}g}'.format(sk3, 6)+'d-9       # lambda_B1 [/s]\n'
    lines[94] =  '       STOICHIOMETRIC_D_1   '+'{:.{}g}'.format(sk4, 6)+'d-1       # S_D_1 [-]\n'
    lines[160] =   '  FILENAME ../gstools_'+i+'_perm.h5' + '\n'
    lines[164] =   '  FILENAME ../gstools_'+i+'_porosity.h5' + '\n'
    lines[170] =   '  FILENAME ../gstools_'+i+'_min_vol.h5' + '\n'
    lines[229] =   '  FINAL_TIME 5400.d0 h\n'
    if '10x' in i:
        lines[152] =   '  NXYZ 100 ' + str(int(i.split('_')[2][0:2])*200) + ' 1\n'
        lines[155] =   '    1.d0 ' + str(int(i.split('_')[2][0:2])*2) + '.d0 1.d0\n'
        lines[246] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[258] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[271] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[278] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[279] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[296] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[304] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
    else:
        lines[152] =   '  NXYZ 100 ' + str(int(i.split('_')[2][0])*200) + ' 1\n'
        lines[155] =   '    1.d0 ' + str(int(i.split('_')[2][0])*2) + '.d0 1.d0\n'
        lines[246] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[258] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[271] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[278] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[279] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[296] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[304] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
    lines[329] =   '  LIQUID_PRESSURE ' + str(int(i.split('_')[2][0])*-210.65*sk15) + 'd0\n'
    lines[1101] =  '    molasses    '+'{:.{}g}'.format(sk7, 6)+'d-5 T\n'
    lines[1112] =  '    molasses    '+'{:.{}g}'.format(sk8, 6)+'d-5 T\n'
    lines[1123] =  '    molasses    '+'{:.{}g}'.format(sk9, 6)+'d-5 T\n'
    lines[1134] =  '    molasses    '+'{:.{}g}'.format(sk10, 6)+'d-5 T\n'
    lines[1104] =  '    Cr(VI)    '+'{:.{}g}'.format(sk11, 6)+'d-5 T\n'
    lines[1115] =  '    Cr(VI)    '+'{:.{}g}'.format(sk12, 6)+'d-5 T\n'
    lines[1126] =  '    Cr(VI)    '+'{:.{}g}'.format(sk13, 6)+'d-5 T\n'
    lines[1137] =  '    Cr(VI)    '+'{:.{}g}'.format(sk14, 6)+'d-5 T\n'

    modified_lines = []
    for line in lines[894:1015]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[894:1015] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[704:869]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str((float(parts[1]) +  round(sk5*200)))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[704:869] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[607:699]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[607:699] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[471:591]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[471:591] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[337:455]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    modified_data = '\n'.join(modified_lines)
    lines[337:455] = modified_data+'\n'

    
    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)

# %%
import random


def modify_lines_highlose(file_path, new_file,i,count, skewed_number, sk2, sk3, sk4, sk5, sk6, sk7, sk8,sk9,sk10,sk11,sk12,sk13,sk14,sk15):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Changing line 100 (index 99 in Python)
    print (i.split('_'))
    #if count%10
    lines[65] =  '       EXPONENT_B           '+'{:.{}g}'.format(skewed_number, 6)+'         # alpha [-]\n'
    lines[79] =  '       RATE_B_1             '+'{:.{}g}'.format(sk2, 6)+'d-5       # lambda_B1 [/s]\n'
    lines[81] =  '       RATE_C             '+'{:.{}g}'.format(sk3, 6)+'d-9       # lambda_B1 [/s]\n'
    lines[94] =  '       STOICHIOMETRIC_D_1   '+'{:.{}g}'.format(sk4, 6)+'d-1       # S_D_1 [-]\n'
    lines[160] =   '  FILENAME ../gstools_'+i+'_perm.h5' + '\n'
    lines[164] =   '  FILENAME ../gstools_'+i+'_porosity.h5' + '\n'
    lines[170] =   '  FILENAME ../gstools_'+i+'_min_vol.h5' + '\n'
    lines[229] =   '  FINAL_TIME 5400.d0 h\n'
    if '10x' in i:
        lines[152] =   '  NXYZ 100 ' + str(int(i.split('_')[2][0:2])*200) + ' 1\n'
        lines[155] =   '    1.d0 ' + str(int(i.split('_')[2][0:2])*2) + '.d0 1.d0\n'
        lines[246] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[258] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[271] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[278] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 0.\n'
        lines[279] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[296] =   '    1. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
        lines[304] =   '    0. ' + str(int(i.split('_')[2][0:2])*2) + ' 1.\n'
    else:
        lines[152] =   '  NXYZ 100 ' + str(int(i.split('_')[2][0])*200) + ' 1\n'
        lines[155] =   '    1.d0 ' + str(int(i.split('_')[2][0])*2) + '.d0 1.d0\n'
        lines[246] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[258] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[271] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[278] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 0.\n'
        lines[279] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[296] =   '    1. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
        lines[304] =   '    0. ' + str(int(i.split('_')[2][0])*2) + ' 1.\n'
    lines[329] =   '  LIQUID_PRESSURE ' + str(int(i.split('_')[2][0])*-210.65*sk15) + 'd0\n'
    lines[1101] =  '    molasses    '+'{:.{}g}'.format(sk7, 6)+'d-5 T\n'
    lines[1112] =  '    molasses    '+'{:.{}g}'.format(sk8, 6)+'d-5 T\n'
    lines[1123] =  '    molasses    '+'{:.{}g}'.format(sk9, 6)+'d-5 T\n'
    lines[1134] =  '    molasses    '+'{:.{}g}'.format(sk10, 6)+'d-5 T\n'
    lines[1104] =  '    Cr(VI)    '+'{:.{}g}'.format(sk11, 6)+'d-5 T\n'
    lines[1115] =  '    Cr(VI)    '+'{:.{}g}'.format(sk12, 6)+'d-5 T\n'
    lines[1126] =  '    Cr(VI)    '+'{:.{}g}'.format(sk13, 6)+'d-5 T\n'
    lines[1137] =  '    Cr(VI)    '+'{:.{}g}'.format(sk14, 6)+'d-5 T\n'

    
    
    modified_lines = []
    for line in lines[856:1020]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str((float(parts[1]) +  round(sk5*200)))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[856:1020] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[607:698]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[607:698] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[471:589]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    # Join the modified lines back into a single string
    modified_data = '\n'.join(modified_lines)
    lines[471:589] = modified_data+'\n'
    
    modified_lines = []
    for line in lines[337:454]:
        parts = line.split()
        if len(parts) >= 2:
            # Add the random amount to the second entry
            parts[1] = str(float(parts[1]) +  round(sk5))
        modified_line = ' '.join(parts)
        modified_lines.append(modified_line)
    modified_data = '\n'.join(modified_lines)
    lines[337:454] = modified_data+'\n'

    
    # Writing the modified content back to the file
    with open(new_file, 'w') as file:
        file.writelines(lines)

# %%
base = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper'

import os
import pandas as pd
import numpy as np
import re
import random

# Define the replacement functions
alpha = 4
beta = 2

alpha2 = 2
beta2 = 4

alpha3 = 4
beta3 = 4
# Scale the number to the desired range (2 to 3)
#min_val = 2
#max_val = 3
#maxv2 = 1.5
#minv2 = 1.1
#maxv3 = 10
#minv3 = .1
# maxv4 = -2
# minv4 = 2
#maxv5 = .5
#minv5 = 2
min_val = 1
max_val = 4
maxv2 = 1.6
minv2 = 0.8
maxv3 = 100
minv3 = .01
# maxv4 = -2
# minv4 = 2
maxv5 = .5
minv5 = 2


file_path = '/home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/fullsim_highlosing_10_5.in'

files = os.listdir(base)
sim_strings=[]
for i in files:
    splt = '_'.join(i.split('_')[1:4])
    if 'h5' not in splt:
        if 'min' in splt:
            sim_strings.append('_'.join(i.split('_')[1:3])+'_1xscale')
        else:    
            sim_strings.append('_'.join(i.split('_')[1:4]))
sims = np.unique(sim_strings)

permeabilities=sims[0:-1]
permeabilities
# Out:
# array(['14_10_10xscale', '14_10_1xscale', '14_10_2xscale',
#        '14_10_5xscale', '17_22_10xscale', '17_22_1xscale',
#        '17_22_2xscale', '17_22_5xscale', '18_10_10xscale',
#        '18_10_1xscale', '18_10_2xscale', '18_10_5xscale',
#        '18_19_10xscale', '18_19_1xscale', '18_19_2xscale',
#        '18_19_5xscale', '22_16_10xscale', '22_16_1xscale',
#        '22_16_2xscale', '22_16_5xscale', '22_21_10xscale',
#        '22_21_1xscale', '22_21_2xscale', '22_21_5xscale',
#        '24_17_10xscale', '24_17_1xscale', '24_17_2xscale',
#        '24_17_5xscale', '25_15_10xscale', '25_15_1xscale',
#        '25_15_2xscale', '25_15_5xscale', '26_16_10xscale',
#        '26_16_1xscale', '26_16_2xscale', '26_16_5xscale',
#        '27_14_10xscale', '27_14_1xscale', '27_14_2xscale',
#        '27_14_5xscale', '27_7_10xscale', '27_7_1xscale', '27_7_2xscale',
#        '27_7_5xscale', '27_8_10xscale', '27_8_1xscale', '27_8_2xscale',
# ...

# %%
count=0
count4=0
for i in permeabilities:
    if count%4 == 0:
        
        if count4%4==0:
            sk4 = .1
        elif count4%4==1:
            sk4 = 1.0
        elif count4%4==2:
            sk4 = 5.0
        else:
            sk4 = 10.0
        number = random.betavariate(alpha, beta)
        n2 = random.betavariate(alpha2, beta2)
        sk6 = np.random.lognormal(mean=0.0, sigma=1.0, size=None)
        sk7 = np.random.lognormal(mean=0.0, sigma=1.0, size=None)
        sk8 = np.random.lognormal(mean=0.0, sigma=1.0, size=None)
        sk9 = np.random.lognormal(mean=0.0, sigma=1.0, size=None)
        sk10 = np.random.lognormal(mean=0.0, sigma=1.0, size=None)
        sk11 = np.random.lognormal(mean=0.0, sigma=1.0, size=None)
        sk12 = np.random.lognormal(mean=0.0, sigma=1.0, size=None)
        sk13 = np.random.lognormal(mean=0.0, sigma=1.0, size=None)
        sk14 = np.random.lognormal(mean=0.0, sigma=1.0, size=None)
        sk15 = random.choice([-5, -4, -3, -2, -1, -5, -.1, 0, .1, 1, 2, 3, 4, 5])
        skewed_number = min_val + (max_val - min_val) * number
        sk2 = minv2 + (maxv2 - minv2) * number
        sk3 = minv3 + (maxv3 - minv3) * n2
        sk5 = random.uniform(-5, 5)

        #sk5 = 


        file_path_new = base+'/input_files/high_losing_'+i+'.in'
        print(file_path_new)
        # Open and read the file
        modify_lines_highlose(file_path, file_path_new, i,count, skewed_number, sk2, sk3, sk4, sk5,sk6,sk7, sk8,sk9,sk10,sk11,sk12,sk13,sk14,sk15)
        count4 = count4+1
    else:
        file_path_new = base+'/input_files/high_losing_'+i+'.in'
        modify_lines_highlose(file_path, file_path_new, i,count, skewed_number, sk2, sk3, sk4, sk5,sk6,sk7, sk8,sk9,sk10,sk11,sk12,sk13,sk14,sk15)
        
    count = count+1
# Out:
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/high_losing_14_10_10xscale.in
# ['14', '10', '10xscale']
# ['14', '10', '1xscale']
# ['14', '10', '2xscale']
# ['14', '10', '5xscale']
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/high_losing_17_22_10xscale.in
# ['17', '22', '10xscale']
# ['17', '22', '1xscale']
# ['17', '22', '2xscale']
# ['17', '22', '5xscale']
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/high_losing_18_10_10xscale.in
# ['18', '10', '10xscale']
# ['18', '10', '1xscale']
# ['18', '10', '2xscale']
# ['18', '10', '5xscale']
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/high_losing_18_19_10xscale.in
# ['18', '19', '10xscale']
# ['18', '19', '1xscale']
# ['18', '19', '2xscale']
# ['18', '19', '5xscale']
# /home/mbadhan/Desktop/mberghouse/PFLOTRAN/one_deeper/input_files/high_losing_22_16_10xscale.in
# ['22', '16', '10xscale']
# ['22', '16', '1xscale']
# ['22', '16', '2xscale']
# ...

# %%
random.choice([-5, -4, -3, -2, -1, -5, -.1, 0, .1, 1, 2, 3, 4, 5])
# Out:
# 0.1

# %%
np.random.lognormal(mean=0.0, sigma=2.0, size=None)
# Out:
# 0.9192287775474556

# %%
count=0
for i in permeabilities:
    if ('1x' in i)|('2x' in i)|('10x' in i):
        print ('mpirun -n 20 $PFLOTRAN_DIR/src/pflotran/pflotran -input_prefix hanford_lose_'+str(i))
        count = count+1
# Out:
# mpirun -n 20 $PFLOTRAN_DIR/src/pflotran/pflotran -input_prefix hanford_lose_14_10_10xscale
# mpirun -n 20 $PFLOTRAN_DIR/src/pflotran/pflotran -input_prefix hanford_lose_14_10_1xscale
# mpirun -n 20 $PFLOTRAN_DIR/src/pflotran/pflotran -input_prefix hanford_lose_14_10_2xscale
# mpirun -n 20 $PFLOTRAN_DIR/src/pflotran/pflotran -input_prefix hanford_lose_17_22_10xscale
# mpirun -n 20 $PFLOTRAN_DIR/src/pflotran/pflotran -input_prefix hanford_lose_17_22_1xscale
# mpirun -n 20 $PFLOTRAN_DIR/src/pflotran/pflotran -input_prefix hanford_lose_17_22_2xscale
# mpirun -n 20 $PFLOTRAN_DIR/src/pflotran/pflotran -input_prefix hanford_lose_18_10_10xscale
# mpirun -n 20 $PFLOTRAN_DIR/src/pflotran/pflotran -input_prefix hanford_lose_18_10_1xscale
# mpirun -n 20 $PFLOTRAN_DIR/src/pflotran/pflotran -input_prefix hanford_lose_18_10_2xscale
# mpirun -n 20 $PFLOTRAN_DIR/src/pflotran/pflotran -input_prefix hanford_lose_18_19_10xscale
# ...

# %%
count//3
# Out:
# 50

# %%
os.listdir('C:/Users/marcb/Desktop/PFLOTRAN_work/chrotran/chrotran_examples/input_files')
# Out:
# ['high_losing_10_5_1xscale.in',
#  'high_losing_10_5_2xscale.in',
#  'high_losing_10_5_4xscale.in',
#  'high_losing_10_5_8xscale.in',
#  'high_losing_20_20_16xscale.in',
#  'high_losing_20_20_1xscale.in',
#  'high_losing_20_20_2xscale.in',
#  'high_losing_20_20_4xscale.in',
#  'high_losing_20_20_8xscale.in',
#  'high_losing_20_5_1xscale.in',
#  'high_losing_20_5_2xscale.in',
#  'high_losing_20_5_4xscale.in',
#  'high_losing_20_5_8xscale.in',
#  'high_losing_30_10_1xscale.in',
#  'high_losing_30_10_2xscale.in',
#  'high_losing_30_10_4xscale.in',
#  'high_losing_30_10_8xscale.in',
#  'high_losing_40_20_1xscale.in',
#  'high_losing_40_20_2xscale.in',
#  'high_losing_40_20_4xscale.in',
#  'high_losing_40_20_8xscale.in',
#  'high_losing_5_10_4xscale.in',
#  'high_losing_5_10_8xscale.in',
#  'high_losing_5_5_1xscale-int.dat',
#  'high_losing_5_5_1xscale.h5',
#  'high_losing_5_5_1xscale.in',
#  'high_losing_5_5_1xscale.out',
#  'high_losing_5_5_2xscale.in',
#  'high_losing_5_5_4xscale.in',
# ...
